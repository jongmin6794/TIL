# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax=plt.subplots()
tips=sns.load_dataset('tips')
tips
ax=sns.regplot(x="total_bill",y='tip', data=tips,fit_reg=False)#fit_reg 데이터는 출력, 선형그래프 출력 x
ax.set_xlabel("TB")
ax.set_ylabel("Tip")
ax.set_title("Total bill and Tip")
# Out:
# Text(0.5, 1.0, 'Total bill and Tip')

# %%
sns.jointplot(x="total_bill", y="tip",data=tips)

# %%
joint=sns.jointplot(x="total_bill",y='tip',data=tips,kind='hex')
joint.set_axis_labels(xlabel="TB",ylabel="Tip")

# %%
#이차원 밀집도 그래프
kde, ax=plt.subplots()
ax=sns.kdeplot(data=tips['total_bill'],data2=tips['tip'],shade=True)
ax.set_title("Kernel Density Plot")
# Out:
# Text(0.5, 1.0, 'Kernel Density Plot')

# %%
ax=plt.subplots()
ax=sns.barplot(x="time",y="total_bill",data=tips)

# %%
# ax=plt.subplots()
# ax=sns.boxplot(x="time",y="total_bill",data=tips, orient="v")
ax=plt.subplots()
ax=sns.boxplot(x="total_bill",data=tips,orient="v")
#orient 는 가로데이터를 세로로

# %%
ax=sns.boxplot(x="day",y="total_bill",data=tips)
#박스 네모 세로 3사분위 - 1사분위 => IQR
#가로선 = 중앙값, 중위수, median
#선 구간 1.5곱한 값

# %%
ax=sns.boxplot(x="day",y="total_bill",data=tips, hue="smoker",
               palette="Set3")

# %%
#seaborn.pydata.org 사이트 시각화 용이

# %%
ax=sns.boxplot(x="day",y="total_bill",data=tips)
sns.swarmplot(x="day",y="total_bill",data=tips)

# %%
ax=plt.subplots()
sns.violinplot(x="time",y='total_bill',data=tips)

# %%
#관계그래프
sns.pairplot(tips)

# %%
pg=sns.PairGrid(tips)
pg.map_upper(sns.regplot)
pg.map_lower(sns.kdeplot)
pg.map_diag(sns.distplot,rug=True)#대각요소

# %%
iris=sns.load_dataset('iris')
titanic=sns.load_dataset('titanic')
flights=sns.load_dataset('flights')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
x=iris.petal_length.values #values없으면 시리즈형태\
sns.rugplot(x)

# %%
sns.kdeplot(x)

# %%
sns.distplot(x,kde=True, rug=True)

# %%
#countplot: 각 종류별 데이터가 얼마나 있는지 표시 
sns.countplot(x="class",data=titanic)

# %%
sns.countplot(x="day",data=tips)

# %%
"""
1차원 데이터:실수값, 실수분포플롯
(커널밀도, 러그, rugplot, kdeplot, distplot)
coutplot:카테고리별 데이터가 얼마나 있는지 나타낼 때

다차원데이터(변수가 여러개)
-2차원 실수형 데이터:스캐터플롯(jointplot)
-3차원 이상의 실수형 데이터 : pairplot(그리드형태로 출력)
(만약 카테고리형 데이터가 포함되어 있다면 hue속성을 지정)
-2차원 카테고리형 데이터 : heatmap
-2차원 실수값, 카테고리형 데이터가 섞여 있는 경우
bar, box, point, violin, swarm plot

"""
# Out:
# '\n1차원 데이터:실수값, 실수분포플롯\n(커널밀도, 러그, rugplot, kdeplot, distplot)\ncoutplot:카테고리별 데이터가 얼마나 있는지 나타낼 때\n\n다차원데이터(변수가 여러개)\n-2차원 실수형 데이터:스캐터플롯(jointplot)\n-3차원 이상의 실수형 데이터 : pairplot(그리드형태로 출력)\n(만약 카테고리형 데이터가 포함되어 있다면 hue속성을 지정)\n-2차원 카테고리형 데이터 : heatmap\n-2차원 실수값, 카테고리형 데이터가 섞여 있는 경우\nbar, box, point, violin, swarm plot\n\n'

# %%
#2차원, 연속적인 실수값
sns.jointplot(x="sepal_length", y="sepal_width", data=iris,
              kind="scatter")

# %%
sns.jointplot(x="sepal_length", y="sepal_width", data=iris,
              kind="kde")

# %%
#3차원 이상 데이터
sns.pairplot(iris,hue="species",markers=["o","s","D"])

# %%
#2차원데이터, 모든 값이 카테고리형
#heatmap
titanic.head()
titanic_size=titanic.pivot_table(index="class",columns="sex", aggfunc="size")
titanic_size
# Out:
# sex     female  male
# class
# First       94   122
# Second      76   108
# Third      144   347

# %%
sns.heatmap(titanic_size,annot=True,fmt="d",
            cmap=sns.light_palette("gray"))

# %%
#2차원 데이터 실수, 카테고리가 섞임
# sns.barplot(x="day",y='total_bill',data=tips)
# sns.boxplot(x="day",y='total_bill',data=tips)
# sns.violinplot(x="day",y='total_bill',data=tips)
#sns.stripplot(x="day",y='total_bill',data=tips, jitter=True)
#jitter - False 직선으로 나옴
sns.swarmplot(x="day",y='total_bill',data=tips)#겹쳐진 것이 1도 없다.

# %%
#요일별, 성별 전체 팀의 히스토 그램
# x-목 금 토 일
# y- total_bill
# data-tips
sns.barplot(x='day',y='total_bill',data=tips,hue="sex")

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue="sex")
# plt.legend(loc=1)

# %%
flights.head()
fp=flights.pivot("month","year","passengers")
sns.heatmap(fp,linewidths=1,annot=True,fmt="d")

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(100,3),
             index=pd.date_range('1/28/2020',periods=100),
            columns=['A','B','C']).cumsum()
#df.cumsum()
df
# Out:
#                     A         B          C
# 2020-01-28   0.383311  0.473330  -0.758481
# 2020-01-29  -0.445934  0.290679  -2.112101
# 2020-01-30  -0.148003  1.270977  -0.984816
# 2020-01-31   0.572558  1.731573  -0.722005
# 2020-02-01   1.624225  2.760833  -3.789642
# ...               ...       ...        ...
# 2020-05-02 -12.160849  5.257988 -11.510032
# 2020-05-03 -13.792476  4.880672 -10.080713
# 2020-05-04 -15.100260  4.706912 -10.303366
# 2020-05-05 -14.904550  5.333092 -10.180972
# 2020-05-06 -14.841453  5.153618 -10.816321
#
# [100 rows x 3 columns]

# %%
df.plot()

# %%
# iris.sepal_length[:20].plot(kind="bar",rot=0)
iris.sepal_length[:20].plot.bar(rot=0)

# %%
df2=iris.groupby(iris.species).mean()
df2
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.428         1.462        0.246
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
df2.plot.bar(rot=0)

# %%
df=titanic.pclass.value_counts()
df.plot.pie(autopct="%.2f%%")

# %%
iris.plot.hist()
iris.plot.kde()

# %%
#선형대수
"""
데이터 개수, 형태에 따라서
스칼라(숫자 1개), 벡터(숫자 여러개), 행렬(벡터가 여러개인 데이터 집합),
텐서(같은 크기 행렬이 여러개 있는 것)

"""
from sklearn.datasets import load_iris
iris.data[0,:]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
iris=load_iris()
iris.data[0,:]
# Out:
# array([5.1, 3.5, 1.4, 0.2])

# %%
#넘파이:선형대수 문제 해결 사용
x1=np.array([[5.1],[3.1],[1.4],[0.2]])
x1
#4차원 벡터, 2차원 배열
np.array([5.1,3.1,1.4,0.2])
# Out:
# array([[5.1],
#        [3.1],
#        [1.4],
#        [0.2]])

# %%
from sklearn.datasets import load_digits
digits=load_digits()
digits
samples=[0,10,20,30,1,11,21,31]

# %%
d=[]
for i in range(8):
    d.append(digits.images[samples[i]])

# %%
plt.figure(figsize=(8,2))
for i in range(8):
    plt.subplot(1,8,i+1)
    plt.imshow(d[i],cmap=plt.cm.bone_r)
    plt.title("image{}".format(i+1))
    plt.grid(False)
    plt.xticks([]);plt.yticks([])

# %%
#2차원 이미지 => 64차원 데이터 => 1차원 벡터

# %%
v=[]
for i in range(8):
    v.append(d[i].reshape(64,1))
    
plt.figure(figsize=(8,2))
for i in range(8):
    plt.subplot(1,8,i+1)
    plt.imshow(v[i],cmap=plt.cm.bone_r)
    plt.title("vector{}".format(i+1))
    plt.grid(False)
    plt.xticks([]);plt.yticks([])

# %%
#행렬
# [x11 x12 x13 x14
#  x11 x12 x13 x14
#  x11 x12 x13 x14
#  x11 x12 x13 x14
# ]
a=np.array([[10,20,30],[40,50,60]])
a
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
# 텐서 : 같은 크기의 행렬이 여러 개 묶여 있는 것
# 다차원 배열 보다는 맵핑에 대해 애기하는 것이 좀더 옳다고 봄
from scipy import misc
img = misc.face()
img.shape
# Out:
# (768, 1024, 3)

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)# 2*2 로 나눔, 1번째 위치 출력
plt.imshow(img, cmap=plt.cm.gray)
plt.axis('off')

plt.subplot(222) # R
plt.imshow(img[:,:,0], cmap=plt.cm.gray)
plt.axis('off')

plt.subplot(223) # G
plt.imshow(img[:,:,1], cmap=plt.cm.gray)
plt.axis('off')

plt.subplot(224) # B
plt.imshow(img[:,:,2], cmap=plt.cm.gray)
plt.axis('off')
# Out:
# (-0.5, 1023.5, 767.5, -0.5)

# %%
#두 벡터와 행렬에서 같은 위치에 있는 요소끼리
#덧셈/뺄셈 수행 => 요소간 연산
x=np.array([1,2])
y=np.array([3,4])
x+y#두 벡터간 덧셈 연산
x-y
# Out:
# array([-2, -2])

# %%
#스칼라와 벡터/행렬간 곱셈

#선형조합 : 벡터/행렬에 스칼라값을 곱한 후 더하거나
#뺀것을 벡터/행렬의 선형조합이라고 함

#내적:두 벡터의 곱셈(dot)
#두 벡터의 차원이 같아야 함
#헹벡터*열벡터
#내적 결과는 스칼라

# %%
x=np.array([[1],[2],[3]])
x
y=np.array([[4],[5],[6]])
y
#np.dot(x.T,y)
x.T@y #@도 내적 기호
# Out:
# array([[32]])

# %%
#데이터벡터, 가중치벡터 => 데이터벡터의 가중치 합

# %%
"""
벡터의 내적은 두 벡터의 유사도를 계산하는데 활용
유사도? 두 벡터가 닮은 정도
코사인 유사도?
"""
# Out:
# '\n벡터의 내적은 두 벡터의 유사도를 계산하는데 활용\n유사도? 두 벡터가 닮은 정도\n코사인 유사도?\n'

# %%
digits=load_digits()
d1=digits.images[0]
d2=digits.images[10]
d3=digits.images[1]
d4=digits.images[11]
#d1과 d2, d3, d4 각각 내적 3개의 내적값에서 유사도 가장 큰것
v1=d1.reshape(64,1)
v2=d2.reshape(64,1)
v3=d3.reshape(64,1)
v4=d4.reshape(64,1)

# %%
plt.figure(figsize=(9,9)) #1당 72pix
import matplotlib.gridspec as gridspec

# %%
gs=gridspec.GridSpec(1,8,height_ratios=[1],
                 width_ratios=[9,1,9,1,9,1,9,1])

# %%
for i in range(4):
    plt.subplot(gs[2*i])
    plt.imshow(eval("d"+str(i+1)),cmap=plt.cm.bone_r)
    plt.subplot(gs[2*i+1])
    plt.imshow(eval("v"+str(i+1)),cmap=plt.cm.bone_r)

# %%
v1 #0
(v1.T@v2)[0][0]#3064 :v1, v2벡터간 내적
(v1.T@v3)[0][0]#1866 :v1, v2벡터간 내적
(v1.T@v4)[0][0]#1883 :v1, v2벡터간 내적
# Out:
# 1883.0

# %%
#v2, v3, v4간 내적
(v2.T@v1)[0][0] #3064
(v2.T@v3)[0][0] #2421
(v2.T@v4)[0][0] #2479
# Out:
# 3064.0

# %%
(v3.T@v1)[0][0] # 1866
(v3.T@v2)[0][0] # 2421
(v3.T@v4)[0][0] # 3661
# Out:
# 3661.0

# %%
#문제1
import numpy as np
p=np.array([100,80,50])
n=np.array([3,4,5])
np=n.T@p
np
# Out:
# 870

# %%
#문제2
from sklearn.datasets import load_digits
import numpy as np
X=load_digits().data
#1)
Xn=X[0].T@X[9]
print(Xn)
#2)
arrX=np.zeros((len(X),len(X)))
listX=[] #로 처음에 append 했으나 제대로 안됨...  list의 사이즈 때문??? 
# 1797*1797-1797 = 3227412나와야 하나  len(listX) 1613706 까지밖에 안나옴
for i in range(0,1796):
    for j in range(i+1,1797):
        arrX[i][j]=X[i].T@X[j]
#         listX.append(X[i].T@X[j])
# print(len(X))
print(len(listX))
print(arrX)
# Out:
# 1797

# %%
#문제3
j1='{"level":3, "attr":{"power":120, "name":"hero"}, "friendIds":[12, 23, 34, 23]}'
j2='[12, 23, 34, "23"]'
j3='{"level":3, "attr":{"power":120, "name":"hero"}, "friendIds":[12, 23, 34, 23}'
j4='["level":3, 23, 34, "23"]'
###일단 3번케이스까지 해결###
def fu(x):#스위치 문과 같은 역할의 함수
    return {'}':'{',']':'[',')':'('}[x]
def check(x):
    lstack=[]
    for i in x:
        if i =='{' or i=='[' or i=='(':
            lstack.append(i)
        if i=='}' or i==']' or i==')':
            if fu(i)!=lstack.pop():
                return "Parse error!"
            if len(lstack)==0:
                return "Valid JSON"
# Out:
# Valid JSON
# Valid JSON
# Parse error!
# Valid JSON

# %%
#문제4
import numpy as np
inpt=np.array([[2,4,1,2,1],
               [3,4,2,3,4],
               [2,4,1,2,2],
               [4,4,4,1,2],
               [4,2,1,3,2]])

# inpt2=inpt.copy()
def playOne(arr1):#1회 펑!!
    arr2=arr1.copy()
    for i in range(4,-1,-1): #x축 검사 & 변경
        count=1
        for j in range(0,4,1):
            if arr1[i][j]==arr1[i][j+1]:
                count+=1
                if count==3:
                    arr2[i][j+1]=0
                    arr2[i][j]=0
                    arr2[i][j-1]=0
                if count>3:
                    arr2[i][j+1]=0
            elif arr1[i][j]!=arr1[i][j+1]:
                count=1
    for j in range(0,5,1): #y축 검사 & 변경
        count=1
        for i in range(4,0,-1):
            if arr1[i][j]==arr1[i-1][j]:
                count+=1
                if count==3:
                    arr2[i-1][j]=0
                    arr2[i][j]=0
                    arr2[i+1][j]=0
                if count>3:
                    arr2[i-1][j]=0
            elif arr1[i][j]!=arr1[i-1][j]:
                count=1    
    arr1=arr2.copy()
    return arr1
def change(arr1):# 1회 펑! 후 빈자리 자리변경!
    return 0
