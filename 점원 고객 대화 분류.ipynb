# %%
import pandas as pd
import numpy as np
import random

# %%
text1=pd.read_excel("C:/Users/student/Downloads/Python_JP/01_dialog/대화데이터/B 의류(15,826).xlsx")
text2=pd.read_excel("C:/Users/student/Downloads/Python_JP/01_dialog/대화데이터/D 소매점(14,949).xlsx")

# %%
type(text1)
# Out:
# pandas.core.frame.DataFrame

# %%
text1[:10]
# Out:
#   SPEAKER                      SENTENCE      DATAID DOMAINID DOMAIN CATEGORY  \
# 0      고객              신발은 여기 있는 게 다예요?  박은영_액세서리_5        B  의복의류점       신발
# 1      점원               네 성인이나 아동 다 있어요  박은영_액세서리_5        B  의복의류점       신발
# 2      점원                 발 사이즈 몇 신으세요?  박은영_액세서리_5        B  의복의류점       신발
# 3      고객                         230이요  박은영_액세서리_5        B  의복의류점       신발
# 4      점원           편하게 신을 수 있는 거 찾으세요?  박은영_액세서리_5        B  의복의류점       신발
# 5      고객          네 봄이니까 편하게 신을 수 있는 거  박은영_액세서리_5        B  의복의류점       신발
# 6      점원  이런 건 어떠세요? 이런 거도 신발 무척 편하거든요  박은영_액세서리_5        B  의복의류점       신발
# 7      고객                 굽 좀 높은 거 없나요?  박은영_액세서리_5        B  의복의류점       신발
# 8      점원     봄 상품은 아직 어른 제품이 많이 안나왔습니다  박은영_액세서리_5        B  의복의류점       신발
# 9      고객                      언제 들어와요?  박은영_액세서리_5        B  의복의류점       신발
#
#    SPEAKERID  SENTENCEID         MAIN   SUB QA  QACNCT                MQ  \
# ...

# %%
temp=text1['SENTENCE'][text1['SPEAKER']=="고객"]

# %%
list(temp.values)
# Out:
# ['신발은 여기 있는 게 다예요?',
#  '230이요',
#  '네 봄이니까 편하게 신을 수 있는 거',
#  '굽 좀 높은 거 없나요?',
#  '언제 들어와요?',
#  '이거는 가죽이에요?',
#  '가죽은 얼마예요?',
#  '털 달린 거 저거는 사이즈 있어요?',
#  '좀 크네',
#  '또 안 들어와요?',
#  '가방 매는 거 보고 있어요',
#  '가격이 얼마예요?',
#  '가죽으로 된 거는 없어요?',
#  '레자는 얼마예요?',
#  '이거는 천이죠?',
#  '이건 얼마예요?',
#  '이거 끈은 따로 없어요?',
#  '내일은 문 열어요?',
#  '며칠까지 휴무예요?',
#  '여기 마스크는 얼마예요?',
#  '이거 나무예요? 다 돌인가요?',
#  '이런 건 세트로 팔아요?',
#  '이건 뭐예요?',
#  '제일 큰 거는 얼마인데요?',
#  '스카프 좀 보려구요',
#  '실크스카프도 봄에 하나요?',
#  '이거는 뭐예요?',
#  '여기 가격은 그대로 파시는 거예요?',
#  '착용해볼 수 있어요?',
#  '이거는 요즘 들어온 거예요?',
#  '세탁은 물세탁되죠?',
#  '지금 여기 있는 게 다예요?',
#  '몇 시에 문 닫아요?',
#  '일요일도 하세요?',
#  '스카프 있어요?',
#  '이런 건 세탁을 어떻게 해요?',
#  '원단은 뭐예요?',
#  '얼마인데요?',
#  '브로치 같은 건 어디 있나요?',
#  '이런 거도 2만 원이예요?',
#  '명품이랑 똑같이 한 거예요?',
#  '온누리 상품권도 되죠?',
#  '브로치하고 머리핀하고 보려고요',
#  '도자기 같은 거 말고 구슬이나 진주 같은 거는 없어요?',
#  '그건 흥미없고',
#  '안에 하면 안 떨어져요?',
#  '얼마예요?',
#  '이 우산은 얼마인데요?',
#  '무겁지 않아요?',
#  '이렇게 다는 거 맞아요?',
#  '자석은 다 3만 원?',
#  '머리핀 종류도 한 번 보여주세요 곱창은 요새 안나와요?',
# ...

# %%
text1

# %%
cust_list1=text1['SENTENCE'][text1['SPEAKER']=="고객"].values
step_list1=text1['SENTENCE'][text1['SPEAKER']=="점원"].values

# %%
cust_list2=text2['SENTENCE'][text1['SPEAKER']=="고객"].values
step_list2=text2['SENTENCE'][text1['SPEAKER']=="점원"].values

# %%
cust_list1=list(cust_list1)
step_list=list(step_list1)
cust_list2=list(cust_list2)
step_list2=list(step_list2)

# %%
cust_list=cust_list1+cust_list2
step_list=step_list1+step_list2

# %%
cust_list
# Out:
# ['신발은 여기 있는 게 다예요?',
#  '230이요',
#  '네 봄이니까 편하게 신을 수 있는 거',
#  '굽 좀 높은 거 없나요?',
#  '언제 들어와요?',
#  '이거는 가죽이에요?',
#  '가죽은 얼마예요?',
#  '털 달린 거 저거는 사이즈 있어요?',
#  '좀 크네',
#  '또 안 들어와요?',
#  '가방 매는 거 보고 있어요',
#  '가격이 얼마예요?',
#  '가죽으로 된 거는 없어요?',
#  '레자는 얼마예요?',
#  '이거는 천이죠?',
#  '이건 얼마예요?',
#  '이거 끈은 따로 없어요?',
#  '내일은 문 열어요?',
#  '며칠까지 휴무예요?',
#  '여기 마스크는 얼마예요?',
#  '이거 나무예요? 다 돌인가요?',
#  '이런 건 세트로 팔아요?',
#  '이건 뭐예요?',
#  '제일 큰 거는 얼마인데요?',
#  '스카프 좀 보려구요',
#  '실크스카프도 봄에 하나요?',
#  '이거는 뭐예요?',
#  '여기 가격은 그대로 파시는 거예요?',
#  '착용해볼 수 있어요?',
#  '이거는 요즘 들어온 거예요?',
#  '세탁은 물세탁되죠?',
#  '지금 여기 있는 게 다예요?',
#  '몇 시에 문 닫아요?',
#  '일요일도 하세요?',
#  '스카프 있어요?',
#  '이런 건 세탁을 어떻게 해요?',
#  '원단은 뭐예요?',
#  '얼마인데요?',
#  '브로치 같은 건 어디 있나요?',
#  '이런 거도 2만 원이예요?',
#  '명품이랑 똑같이 한 거예요?',
#  '온누리 상품권도 되죠?',
#  '브로치하고 머리핀하고 보려고요',
#  '도자기 같은 거 말고 구슬이나 진주 같은 거는 없어요?',
#  '그건 흥미없고',
#  '안에 하면 안 떨어져요?',
#  '얼마예요?',
#  '이 우산은 얼마인데요?',
#  '무겁지 않아요?',
#  '이렇게 다는 거 맞아요?',
#  '자석은 다 3만 원?',
#  '머리핀 종류도 한 번 보여주세요 곱창은 요새 안나와요?',
# ...

# %%
len(cust_list)
# Out:
# 15885

# %%
li = [1, 2, 3] # 리스트에서 2개 랜덤 추출 
sampleList = random.sample(li, 2)
